# %% [markdown]
# # MobileViT: A mobile-friendly Transformer-based model for image classification
#
# **Author:** [Sayak Paul](https://twitter.com/RisingSayak)<br>
# **Date created:** 2021/10/20<br>
# **Last modified:** 2025/09/30<br>
# **Description:** MobileViT for image classification with combined benefits of convolutions and Transformers.

# %% [markdown]
# ## Introduction
#
# In this example, we implement the MobileViT architecture
# ([Mehta et al.](https://arxiv.org/abs/2110.02178)),
# which combines the benefits of Transformers
# ([Vaswani et al.](https://arxiv.org/abs/1706.03762))
# and convolutions. With Transformers, we can capture long-range dependencies that result
# in global representations. With convolutions, we can capture spatial relationships that
# model locality.
#
# Besides combining the properties of Transformers and convolutions, the authors introduce
# MobileViT as a general-purpose mobile-friendly backbone for different image recognition
# tasks. Their findings suggest that, performance-wise, MobileViT is better than other
# models with the same or higher complexity ([MobileNetV3](https://arxiv.org/abs/1905.02244),
# for example), while being efficient on mobile devices.
#
# Note: This example should be run with Tensorflow 2.13 and higher.

# %% [markdown]
# ## Imports

# %%
import os
import tensorflow as tf

os.environ["KERAS_BACKEND"] = "tensorflow"

import keras
from keras import layers
from keras import backend

import tensorflow_datasets as tfds

tfds.disable_progress_bar()

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Hyperparameters

# %%
# Values are from table 4.
patch_size = 4  # 2x2, for the Transformer blocks.
image_size = 256
expansion_factor = 2  # expansion factor for the MobileNetV2 blocks.

# %% [markdown]
# ## MobileViT utilities
#
# The MobileViT architecture is comprised of the following blocks:
#
# * Strided 3x3 convolutions that process the input image.
# * [MobileNetV2](https://arxiv.org/abs/1801.04381)-style inverted residual blocks for
# downsampling the resolution of the intermediate feature maps.
# * MobileViT blocks that combine the benefits of Transformers and convolutions. It is
# presented in the figure below (taken from the
# [original paper](https://arxiv.org/abs/2110.02178)):
#
#
# ![](https://i.imgur.com/mANnhI7.png)

# %%
def conv_block(x, filters=16, kernel_size=3, strides=2):
    conv_layer = layers.Conv2D(
        filters,
        kernel_size,
        strides=strides,
        activation=keras.activations.swish,
        padding="same",
    )
    return conv_layer(x)


# Reference: https://github.com/keras-team/keras/blob/e3858739d178fe16a0c77ce7fab88b0be6dbbdc7/keras/applications/imagenet_utils.py#L413C17-L435


def correct_pad(inputs, kernel_size):
    img_dim = 2 if backend.image_data_format() == "channels_first" else 1
    input_size = inputs.shape[img_dim : (img_dim + 2)]
    if isinstance(kernel_size, int):
        kernel_size = (kernel_size, kernel_size)
    if input_size[0] is None:
        adjust = (1, 1)
    else:
        adjust = (1 - input_size[0] % 2, 1 - input_size[1] % 2)
    correct = (kernel_size[0] // 2, kernel_size[1] // 2)
    return (
        (correct[0] - adjust[0], correct[0]),
        (correct[1] - adjust[1], correct[1]),
    )


# Reference: https://git.io/JKgtC


def inverted_residual_block(x, expanded_channels, output_channels, strides=1):
    m = layers.Conv2D(expanded_channels, 1, padding="same", use_bias=False)(x)
    m = layers.BatchNormalization()(m)
    m = keras.activations.swish(m)

    if strides == 2:
        m = layers.ZeroPadding2D(padding=correct_pad(m, 3))(m)
    m = layers.DepthwiseConv2D(
        3, strides=strides, padding="same" if strides == 1 else "valid", use_bias=False
    )(m)
    m = layers.BatchNormalization()(m)
    m = keras.activations.swish(m)

    m = layers.Conv2D(output_channels, 1, padding="same", use_bias=False)(m)
    m = layers.BatchNormalization()(m)

    if keras.ops.equal(x.shape[-1], output_channels) and strides == 1:
        return layers.Add()([m, x])
    return m


# Reference:
# https://keras.io/examples/vision/image_classification_with_vision_transformer/


def mlp(x, hidden_units, dropout_rate):
    for units in hidden_units:
        x = layers.Dense(units, activation=keras.activations.swish)(x)
        x = layers.Dropout(dropout_rate)(x)
    return x


def transformer_block(x, transformer_layers, projection_dim, num_heads=2):
    for _ in range(transformer_layers):
        # Layer normalization 1.
        x1 = layers.LayerNormalization(epsilon=1e-6)(x)
        # Create a multi-head attention layer.
        attention_output = layers.MultiHeadAttention(
            num_heads=num_heads, key_dim=projection_dim, dropout=0.1
        )(x1, x1)
        # Skip connection 1.
        x2 = layers.Add()([attention_output, x])
        # Layer normalization 2.
        x3 = layers.LayerNormalization(epsilon=1e-6)(x2)
        # MLP.
        x3 = mlp(
            x3,
            hidden_units=[x.shape[-1] * 2, x.shape[-1]],
            dropout_rate=0.1,
        )
        # Skip connection 2.
        x = layers.Add()([x3, x2])

    return x


def mobilevit_block(x, num_blocks, projection_dim, strides=1):
    # Local projection with convolutions.
    local_features = conv_block(x, filters=projection_dim, strides=strides)
    local_features = conv_block(
        local_features, filters=projection_dim, kernel_size=1, strides=strides
    )

    # Unfold into patches and then pass through Transformers.
    num_patches = int((local_features.shape[1] * local_features.shape[2]) / patch_size)
    non_overlapping_patches = layers.Reshape((patch_size, num_patches, projection_dim))(
        local_features
    )
    global_features = transformer_block(
        non_overlapping_patches, num_blocks, projection_dim
    )

    # Fold into conv-like feature-maps.
    folded_feature_map = layers.Reshape((*local_features.shape[1:-1], projection_dim))(
        global_features
    )

    # Apply point-wise conv -> concatenate with the input features.
    folded_feature_map = conv_block(
        folded_feature_map, filters=x.shape[-1], kernel_size=1, strides=strides
    )
    local_global_features = layers.Concatenate(axis=-1)([x, folded_feature_map])

    # Fuse the local and global features using a convoluion layer.
    local_global_features = conv_block(
        local_global_features, filters=projection_dim, strides=strides
    )

    return local_global_features

# %% [markdown]
# **More on the MobileViT block**:
#
# * First, the feature representations (A) go through convolution blocks that capture local
# relationships. The expected shape of a single entry here would be `(h, w, num_channels)`.
# * Then they get unfolded into another vector with shape `(p, n, num_channels)`,
# where `p` is the area of a small patch, and `n` is `(h * w) / p`. So, we end up with `n`
# non-overlapping patches.
# * This unfolded vector is then passed through a Tranformer block that captures global
# relationships between the patches.
# * The output vector (B) is again folded into a vector of shape `(h, w, num_channels)`
# resembling a feature map coming out of convolutions.
#
# Vectors A and B are then passed through two more convolutional layers to fuse the local
# and global representations. Notice how the spatial resolution of the final vector remains
# unchanged at this point. The authors also present an explanation of how the MobileViT
# block resembles a convolution block of a CNN. For more details, please refer to the
# original paper.

# %% [markdown]
# Next, we combine these blocks together and implement the MobileViT architecture (XXS
# variant). The following figure (taken from the original paper) presents a schematic
# representation of the architecture:
#
# ![](https://i.ibb.co/sRbVRBN/image.png)

# %%
def create_mobilevit(num_classes=5):
    inputs = keras.Input((image_size, image_size, 3))
    x = layers.Rescaling(scale=1.0 / 255)(inputs)

    # Initial conv-stem -> MV2 block.
    x = conv_block(x, filters=16)
    x = inverted_residual_block(
        x, expanded_channels=16 * expansion_factor, output_channels=16
    )

    # Downsampling with MV2 block.
    x = inverted_residual_block(
        x, expanded_channels=16 * expansion_factor, output_channels=24, strides=2
    )
    x = inverted_residual_block(
        x, expanded_channels=24 * expansion_factor, output_channels=24
    )
    x = inverted_residual_block(
        x, expanded_channels=24 * expansion_factor, output_channels=24
    )

    # First MV2 -> MobileViT block.
    x = inverted_residual_block(
        x, expanded_channels=24 * expansion_factor, output_channels=48, strides=2
    )
    x = mobilevit_block(x, num_blocks=2, projection_dim=64)

    # Second MV2 -> MobileViT block.
    x = inverted_residual_block(
        x, expanded_channels=64 * expansion_factor, output_channels=64, strides=2
    )
    x = mobilevit_block(x, num_blocks=4, projection_dim=80)

    # Third MV2 -> MobileViT block.
    x = inverted_residual_block(
        x, expanded_channels=80 * expansion_factor, output_channels=80, strides=2
    )
    x = mobilevit_block(x, num_blocks=3, projection_dim=96)
    x = conv_block(x, filters=320, kernel_size=1, strides=1)

    # Classification head.
    x = layers.GlobalAvgPool2D()(x)
    outputs = layers.Dense(num_classes, activation="softmax")(x)

    return keras.Model(inputs, outputs)


mobilevit_xxs = create_mobilevit()
mobilevit_xxs.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 256, 256,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ rescaling           │ (None, 256, 256,  │          0 │ input_layer[0][0] │
# │ (Rescaling)         │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d (Conv2D)     │ (None, 128, 128,  │        448 │ rescaling[0][0]   │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1 (Conv2D)   │ (None, 128, 128,  │        512 │ conv2d[0][0]      │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalization │ (None, 128, 128,  │        128 │ conv2d_1[0][0]    │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ silu (Silu)         │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ depthwise_conv2d    │ (None, 128, 128,  │        288 │ silu[0][0]        │
# │ (DepthwiseConv2D)   │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        128 │ depthwise_conv2d… │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ silu_1 (Silu)       │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_2 (Conv2D)   │ (None, 128, 128,  │        512 │ silu_1[0][0]      │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │         64 │ conv2d_2[0][0]    │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add (Add)           │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │                     │ 16)               │            │ conv2d[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_3 (Conv2D)   │ (None, 128, 128,  │        512 │ add[0][0]         │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        128 │ conv2d_3[0][0]    │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ silu_2 (Silu)       │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ zero_padding2d      │ (None, 129, 129,  │          0 │ silu_2[0][0]      │
# │ (ZeroPadding2D)     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ depthwise_conv2d_1  │ (None, 64, 64,    │        288 │ zero_padding2d[0… │
# │ (DepthwiseConv2D)   │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        128 │ depthwise_conv2d… │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ silu_3 (Silu)       │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_4 (Conv2D)   │ (None, 64, 64,    │        768 │ silu_3[0][0]      │
# │                     │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │         96 │ conv2d_4[0][0]    │
# │ (BatchNormalizatio… │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_5 (Conv2D)   │ (None, 64, 64,    │      1,152 │ batch_normalizat… │
# │                     │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        192 │ conv2d_5[0][0]    │
# │ (BatchNormalizatio… │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ silu_4 (Silu)       │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │                     │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ depthwise_conv2d_2  │ (None, 64, 64,    │        432 │ silu_4[0][0]      │
# │ (DepthwiseConv2D)   │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        192 │ depthwise_conv2d… │
# │ (BatchNormalizatio… │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ silu_5 (Silu)       │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │                     │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_6 (Conv2D)   │ (None, 64, 64,    │      1,152 │ silu_5[0][0]      │
# │                     │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │         96 │ conv2d_6[0][0]    │
# │ (BatchNormalizatio… │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_1 (Add)         │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │                     │ 24)               │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_7 (Conv2D)   │ (None, 64, 64,    │      1,152 │ add_1[0][0]       │
# │                     │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        192 │ conv2d_7[0][0]    │
# │ (BatchNormalizatio… │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ silu_6 (Silu)       │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │                     │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ depthwise_conv2d_3  │ (None, 64, 64,    │        432 │ silu_6[0][0]      │
# │ (DepthwiseConv2D)   │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        192 │ depthwise_conv2d… │
# │ (BatchNormalizatio… │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ silu_7 (Silu)       │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │                     │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_8 (Conv2D)   │ (None, 64, 64,    │      1,152 │ silu_7[0][0]      │
# │                     │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │         96 │ conv2d_8[0][0]    │
# │ (BatchNormalizatio… │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_2 (Add)         │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │                     │ 24)               │            │ add_1[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_9 (Conv2D)   │ (None, 64, 64,    │      1,152 │ add_2[0][0]       │
# │                     │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        192 │ conv2d_9[0][0]    │
# │ (BatchNormalizatio… │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ silu_8 (Silu)       │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │                     │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ zero_padding2d_1    │ (None, 65, 65,    │          0 │ silu_8[0][0]      │
# │ (ZeroPadding2D)     │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ depthwise_conv2d_4  │ (None, 32, 32,    │        432 │ zero_padding2d_1… │
# │ (DepthwiseConv2D)   │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        192 │ depthwise_conv2d… │
# │ (BatchNormalizatio… │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ silu_9 (Silu)       │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │                     │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_10 (Conv2D)  │ (None, 32, 32,    │      2,304 │ silu_9[0][0]      │
# │                     │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        192 │ conv2d_10[0][0]   │
# │ (BatchNormalizatio… │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_11 (Conv2D)  │ (None, 32, 32,    │     27,712 │ batch_normalizat… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_12 (Conv2D)  │ (None, 32, 32,    │      4,160 │ conv2d_11[0][0]   │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reshape (Reshape)   │ (None, 4, 256,    │          0 │ conv2d_12[0][0]   │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalization │ (None, 4, 256,    │        128 │ reshape[0][0]     │
# │ (LayerNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multi_head_attenti… │ (None, 4, 256,    │     33,216 │ layer_normalizat… │
# │ (MultiHeadAttentio… │ 64)               │            │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_3 (Add)         │ (None, 4, 256,    │          0 │ multi_head_atten… │
# │                     │ 64)               │            │ reshape[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 4, 256,    │        128 │ add_3[0][0]       │
# │ (LayerNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 4, 256,    │      8,320 │ layer_normalizat… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_1 (Dropout) │ (None, 4, 256,    │          0 │ dense[0][0]       │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 4, 256,    │      8,256 │ dropout_1[0][0]   │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_2 (Dropout) │ (None, 4, 256,    │          0 │ dense_1[0][0]     │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_4 (Add)         │ (None, 4, 256,    │          0 │ dropout_2[0][0],  │
# │                     │ 64)               │            │ add_3[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 4, 256,    │        128 │ add_4[0][0]       │
# │ (LayerNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multi_head_attenti… │ (None, 4, 256,    │     33,216 │ layer_normalizat… │
# │ (MultiHeadAttentio… │ 64)               │            │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_5 (Add)         │ (None, 4, 256,    │          0 │ multi_head_atten… │
# │                     │ 64)               │            │ add_4[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 4, 256,    │        128 │ add_5[0][0]       │
# │ (LayerNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_2 (Dense)     │ (None, 4, 256,    │      8,320 │ layer_normalizat… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_4 (Dropout) │ (None, 4, 256,    │          0 │ dense_2[0][0]     │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_3 (Dense)     │ (None, 4, 256,    │      8,256 │ dropout_4[0][0]   │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_5 (Dropout) │ (None, 4, 256,    │          0 │ dense_3[0][0]     │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_6 (Add)         │ (None, 4, 256,    │          0 │ dropout_5[0][0],  │
# │                     │ 64)               │            │ add_5[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reshape_1 (Reshape) │ (None, 32, 32,    │          0 │ add_6[0][0]       │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_13 (Conv2D)  │ (None, 32, 32,    │      3,120 │ reshape_1[0][0]   │
# │                     │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate         │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (Concatenate)       │ 96)               │            │ conv2d_13[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_14 (Conv2D)  │ (None, 32, 32,    │     55,360 │ concatenate[0][0] │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_15 (Conv2D)  │ (None, 32, 32,    │      8,192 │ conv2d_14[0][0]   │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ conv2d_15[0][0]   │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ silu_10 (Silu)      │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ zero_padding2d_2    │ (None, 33, 33,    │          0 │ silu_10[0][0]     │
# │ (ZeroPadding2D)     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ depthwise_conv2d_5  │ (None, 16, 16,    │      1,152 │ zero_padding2d_2… │
# │ (DepthwiseConv2D)   │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │        512 │ depthwise_conv2d… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ silu_11 (Silu)      │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_16 (Conv2D)  │ (None, 16, 16,    │      8,192 │ silu_11[0][0]     │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │        256 │ conv2d_16[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_17 (Conv2D)  │ (None, 16, 16,    │     46,160 │ batch_normalizat… │
# │                     │ 80)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_18 (Conv2D)  │ (None, 16, 16,    │      6,480 │ conv2d_17[0][0]   │
# │                     │ 80)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reshape_2 (Reshape) │ (None, 4, 64, 80) │          0 │ conv2d_18[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 4, 64, 80) │        160 │ reshape_2[0][0]   │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multi_head_attenti… │ (None, 4, 64, 80) │     51,760 │ layer_normalizat… │
# │ (MultiHeadAttentio… │                   │            │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_7 (Add)         │ (None, 4, 64, 80) │          0 │ multi_head_atten… │
# │                     │                   │            │ reshape_2[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 4, 64, 80) │        160 │ add_7[0][0]       │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_4 (Dense)     │ (None, 4, 64,     │     12,960 │ layer_normalizat… │
# │                     │ 160)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_7 (Dropout) │ (None, 4, 64,     │          0 │ dense_4[0][0]     │
# │                     │ 160)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_5 (Dense)     │ (None, 4, 64, 80) │     12,880 │ dropout_7[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_8 (Dropout) │ (None, 4, 64, 80) │          0 │ dense_5[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_8 (Add)         │ (None, 4, 64, 80) │          0 │ dropout_8[0][0],  │
# │                     │                   │            │ add_7[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 4, 64, 80) │        160 │ add_8[0][0]       │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multi_head_attenti… │ (None, 4, 64, 80) │     51,760 │ layer_normalizat… │
# │ (MultiHeadAttentio… │                   │            │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_9 (Add)         │ (None, 4, 64, 80) │          0 │ multi_head_atten… │
# │                     │                   │            │ add_8[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 4, 64, 80) │        160 │ add_9[0][0]       │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_6 (Dense)     │ (None, 4, 64,     │     12,960 │ layer_normalizat… │
# │                     │ 160)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_10          │ (None, 4, 64,     │          0 │ dense_6[0][0]     │
# │ (Dropout)           │ 160)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_7 (Dense)     │ (None, 4, 64, 80) │     12,880 │ dropout_10[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_11          │ (None, 4, 64, 80) │          0 │ dense_7[0][0]     │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_10 (Add)        │ (None, 4, 64, 80) │          0 │ dropout_11[0][0], │
# │                     │                   │            │ add_9[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 4, 64, 80) │        160 │ add_10[0][0]      │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multi_head_attenti… │ (None, 4, 64, 80) │     51,760 │ layer_normalizat… │
# │ (MultiHeadAttentio… │                   │            │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_11 (Add)        │ (None, 4, 64, 80) │          0 │ multi_head_atten… │
# │                     │                   │            │ add_10[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 4, 64, 80) │        160 │ add_11[0][0]      │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_8 (Dense)     │ (None, 4, 64,     │     12,960 │ layer_normalizat… │
# │                     │ 160)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_13          │ (None, 4, 64,     │          0 │ dense_8[0][0]     │
# │ (Dropout)           │ 160)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_9 (Dense)     │ (None, 4, 64, 80) │     12,880 │ dropout_13[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_14          │ (None, 4, 64, 80) │          0 │ dense_9[0][0]     │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_12 (Add)        │ (None, 4, 64, 80) │          0 │ dropout_14[0][0], │
# │                     │                   │            │ add_11[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 4, 64, 80) │        160 │ add_12[0][0]      │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multi_head_attenti… │ (None, 4, 64, 80) │     51,760 │ layer_normalizat… │
# │ (MultiHeadAttentio… │                   │            │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_13 (Add)        │ (None, 4, 64, 80) │          0 │ multi_head_atten… │
# │                     │                   │            │ add_12[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 4, 64, 80) │        160 │ add_13[0][0]      │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_10 (Dense)    │ (None, 4, 64,     │     12,960 │ layer_normalizat… │
# │                     │ 160)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_16          │ (None, 4, 64,     │          0 │ dense_10[0][0]    │
# │ (Dropout)           │ 160)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_11 (Dense)    │ (None, 4, 64, 80) │     12,880 │ dropout_16[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_17          │ (None, 4, 64, 80) │          0 │ dense_11[0][0]    │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_14 (Add)        │ (None, 4, 64, 80) │          0 │ dropout_17[0][0], │
# │                     │                   │            │ add_13[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reshape_3 (Reshape) │ (None, 16, 16,    │          0 │ add_14[0][0]      │
# │                     │ 80)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_19 (Conv2D)  │ (None, 16, 16,    │      5,184 │ reshape_3[0][0]   │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_1       │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │ (Concatenate)       │ 128)              │            │ conv2d_19[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_20 (Conv2D)  │ (None, 16, 16,    │     92,240 │ concatenate_1[0]… │
# │                     │ 80)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_21 (Conv2D)  │ (None, 16, 16,    │     12,800 │ conv2d_20[0][0]   │
# │                     │ 160)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │        640 │ conv2d_21[0][0]   │
# │ (BatchNormalizatio… │ 160)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ silu_12 (Silu)      │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │                     │ 160)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ zero_padding2d_3    │ (None, 17, 17,    │          0 │ silu_12[0][0]     │
# │ (ZeroPadding2D)     │ 160)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ depthwise_conv2d_6  │ (None, 8, 8, 160) │      1,440 │ zero_padding2d_3… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 8, 8, 160) │        640 │ depthwise_conv2d… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ silu_13 (Silu)      │ (None, 8, 8, 160) │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_22 (Conv2D)  │ (None, 8, 8, 80)  │     12,800 │ silu_13[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 8, 8, 80)  │        320 │ conv2d_22[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_23 (Conv2D)  │ (None, 8, 8, 96)  │     69,216 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_24 (Conv2D)  │ (None, 8, 8, 96)  │      9,312 │ conv2d_23[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reshape_4 (Reshape) │ (None, 4, 16, 96) │          0 │ conv2d_24[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 4, 16, 96) │        192 │ reshape_4[0][0]   │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multi_head_attenti… │ (None, 4, 16, 96) │     74,400 │ layer_normalizat… │
# │ (MultiHeadAttentio… │                   │            │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_15 (Add)        │ (None, 4, 16, 96) │          0 │ multi_head_atten… │
# │                     │                   │            │ reshape_4[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 4, 16, 96) │        192 │ add_15[0][0]      │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_12 (Dense)    │ (None, 4, 16,     │     18,624 │ layer_normalizat… │
# │                     │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_19          │ (None, 4, 16,     │          0 │ dense_12[0][0]    │
# │ (Dropout)           │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_13 (Dense)    │ (None, 4, 16, 96) │     18,528 │ dropout_19[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_20          │ (None, 4, 16, 96) │          0 │ dense_13[0][0]    │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_16 (Add)        │ (None, 4, 16, 96) │          0 │ dropout_20[0][0], │
# │                     │                   │            │ add_15[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 4, 16, 96) │        192 │ add_16[0][0]      │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multi_head_attenti… │ (None, 4, 16, 96) │     74,400 │ layer_normalizat… │
# │ (MultiHeadAttentio… │                   │            │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_17 (Add)        │ (None, 4, 16, 96) │          0 │ multi_head_atten… │
# │                     │                   │            │ add_16[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 4, 16, 96) │        192 │ add_17[0][0]      │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_14 (Dense)    │ (None, 4, 16,     │     18,624 │ layer_normalizat… │
# │                     │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_22          │ (None, 4, 16,     │          0 │ dense_14[0][0]    │
# │ (Dropout)           │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_15 (Dense)    │ (None, 4, 16, 96) │     18,528 │ dropout_22[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_23          │ (None, 4, 16, 96) │          0 │ dense_15[0][0]    │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_18 (Add)        │ (None, 4, 16, 96) │          0 │ dropout_23[0][0], │
# │                     │                   │            │ add_17[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 4, 16, 96) │        192 │ add_18[0][0]      │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multi_head_attenti… │ (None, 4, 16, 96) │     74,400 │ layer_normalizat… │
# │ (MultiHeadAttentio… │                   │            │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_19 (Add)        │ (None, 4, 16, 96) │          0 │ multi_head_atten… │
# │                     │                   │            │ add_18[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 4, 16, 96) │        192 │ add_19[0][0]      │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_16 (Dense)    │ (None, 4, 16,     │     18,624 │ layer_normalizat… │
# │                     │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_25          │ (None, 4, 16,     │          0 │ dense_16[0][0]    │
# │ (Dropout)           │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_17 (Dense)    │ (None, 4, 16, 96) │     18,528 │ dropout_25[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_26          │ (None, 4, 16, 96) │          0 │ dense_17[0][0]    │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_20 (Add)        │ (None, 4, 16, 96) │          0 │ dropout_26[0][0], │
# │                     │                   │            │ add_19[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reshape_5 (Reshape) │ (None, 8, 8, 96)  │          0 │ add_20[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_25 (Conv2D)  │ (None, 8, 8, 80)  │      7,760 │ reshape_5[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_2       │ (None, 8, 8, 160) │          0 │ batch_normalizat… │
# │ (Concatenate)       │                   │            │ conv2d_25[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_26 (Conv2D)  │ (None, 8, 8, 96)  │    138,336 │ concatenate_2[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_27 (Conv2D)  │ (None, 8, 8, 320) │     31,040 │ conv2d_26[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 320)       │          0 │ conv2d_27[0][0]   │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_18 (Dense)    │ (None, 5)         │      1,605 │ global_average_p… │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 1,307,621 (4.99 MB)
#  Trainable params: 1,305,077 (4.98 MB)
#  Non-trainable params: 2,544 (9.94 KB)

# %% [markdown]
# ## Dataset preparation
#
# We will be using the
# [`tf_flowers`](https://www.tensorflow.org/datasets/catalog/tf_flowers)
# dataset to demonstrate the model. Unlike other Transformer-based architectures,
# MobileViT uses a simple augmentation pipeline primarily because it has the properties
# of a CNN.

# %%
batch_size = 64
auto = tf.data.AUTOTUNE
resize_bigger = 280
num_classes = 5


def preprocess_dataset(is_training=True):
    def _pp(image, label):
        if is_training:
            # Resize to a bigger spatial resolution and take the random
            # crops.
            image = tf.image.resize(image, (resize_bigger, resize_bigger))
            image = tf.image.random_crop(image, (image_size, image_size, 3))
            image = tf.image.random_flip_left_right(image)
        else:
            image = tf.image.resize(image, (image_size, image_size))
        label = tf.one_hot(label, depth=num_classes)
        return image, label

    return _pp


def prepare_dataset(dataset, is_training=True):
    if is_training:
        dataset = dataset.shuffle(batch_size * 10)
    dataset = dataset.map(preprocess_dataset(is_training), num_parallel_calls=auto)
    return dataset.batch(batch_size).prefetch(auto)

# %% [markdown]
# The authors use a multi-scale data sampler to help the model learn representations of
# varied scales. In this example, we discard this part.

# %% [markdown]
# ## Load and prepare the dataset

# %%
train_dataset, val_dataset = tfds.load(
    "tf_flowers", split=["train[:90%]", "train[90%:]"], as_supervised=True
)

num_train = train_dataset.cardinality()
num_val = val_dataset.cardinality()
print(f"Number of training examples: {num_train}")
print(f"Number of validation examples: {num_val}")

train_dataset = prepare_dataset(train_dataset, is_training=True)
val_dataset = prepare_dataset(val_dataset, is_training=False)
# Out:
# WARNING:absl:Variant folder /root/tensorflow_datasets/tf_flowers/3.0.1 has no dataset_info.json
# Downloading and preparing dataset Unknown size (download: Unknown size, generated: Unknown size, total: Unknown size) to /root/tensorflow_datasets/tf_flowers/3.0.1...
# Dataset tf_flowers downloaded and prepared to /root/tensorflow_datasets/tf_flowers/3.0.1. Subsequent calls will reuse this data.
# Number of training examples: 3303
# Number of validation examples: 367

# %% [markdown]
# ## Train a MobileViT (XXS) model

# %%
learning_rate = 0.002
label_smoothing_factor = 0.1
epochs = 20

optimizer = keras.optimizers.Adam(learning_rate=learning_rate)
loss_fn = keras.losses.CategoricalCrossentropy(label_smoothing=label_smoothing_factor)


def run_experiment(epochs=epochs):
    mobilevit_xxs = create_mobilevit(num_classes=num_classes)
    mobilevit_xxs.compile(optimizer=optimizer, loss=loss_fn, metrics=["accuracy"])

    # When using `save_weights_only=True` in `ModelCheckpoint`, the filepath provided must end in `.weights.h5`
    checkpoint_filepath = "/tmp/checkpoint.weights.h5"
    checkpoint_callback = keras.callbacks.ModelCheckpoint(
        checkpoint_filepath,
        monitor="val_accuracy",
        save_best_only=True,
        save_weights_only=True,
    )

    mobilevit_xxs.fit(
        train_dataset,
        validation_data=val_dataset,
        epochs=epochs,
        callbacks=[checkpoint_callback],
    )
    mobilevit_xxs.load_weights(checkpoint_filepath)
    _, accuracy = mobilevit_xxs.evaluate(val_dataset)
    print(f"Validation accuracy: {round(accuracy * 100, 2)}%")
    return mobilevit_xxs


mobilevit_xxs = run_experiment()
# Out:
# Epoch 1/20
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 226s 2s/step - accuracy: 0.4720 - loss: 1.3510 - val_accuracy: 0.2071 - val_loss: 1.7396
# Epoch 2/20
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 32s 380ms/step - accuracy: 0.5886 - loss: 1.1456 - val_accuracy: 0.1907 - val_loss: 1.6476
# Epoch 3/20
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 21s 402ms/step - accuracy: 0.6503 - loss: 1.0531 - val_accuracy: 0.2044 - val_loss: 1.6440
# Epoch 4/20
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 21s 406ms/step - accuracy: 0.6854 - loss: 0.9962 - val_accuracy: 0.1907 - val_loss: 1.9999
# Epoch 5/20
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 21s 394ms/step - accuracy: 0.6997 - loss: 0.9549 - val_accuracy: 0.1662 - val_loss: 2.5907
# Epoch 6/20
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 20s 390ms/step - accuracy: 0.7336 - loss: 0.9217 - val_accuracy: 0.1907 - val_loss: 3.4233
# Epoch 7/20
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 21s 412ms/step - accuracy: 0.7472 - loss: 0.9021 - val_accuracy: 0.1907 - val_loss: 2.4736
# Epoch 8/20
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 21s 397ms/step - accuracy: 0.7545 - loss: 0.8800 - val_accuracy: 0.1907 - val_loss: 2.4398
# Epoch 9/20
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 22s 415ms/step - accuracy: 0.7657 - loss: 0.8622 - val_accuracy: 0.2480 - val_loss: 2.2449
# Epoch 10/20
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 21s 409ms/step - accuracy: 0.7757 - loss: 0.8353 - val_accuracy: 0.5123 - val_loss: 1.4089
# Epoch 11/20
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 22s 415ms/step - accuracy: 0.7829 - loss: 0.8261 - val_accuracy: 0.5831 - val_loss: 1.4001
# Epoch 12/20
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 22s 415ms/step - accuracy: 0.8005 - loss: 0.7958 - val_accuracy: 0.7929 - val_loss: 0.8259
# Epoch 13/20
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 21s 399ms/step - accuracy: 0.8126 - loss: 0.7849 - val_accuracy: 0.7711 - val_loss: 0.8516
# Epoch 14/20
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 21s 396ms/step - accuracy: 0.8108 - loss: 0.7781 - val_accuracy: 0.7548 - val_loss: 0.9209
# Epoch 15/20
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 21s 397ms/step - accuracy: 0.8111 - loss: 0.7713 - val_accuracy: 0.7084 - val_loss: 0.9892
# Epoch 16/20
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 21s 396ms/step - accuracy: 0.8302 - loss: 0.7400 - val_accuracy: 0.7820 - val_loss: 0.8550
# Epoch 17/20
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 21s 398ms/step - accuracy: 0.8277 - loss: 0.7536 - val_accuracy: 0.7084 - val_loss: 0.9913
# Epoch 18/20
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 21s 396ms/step - accuracy: 0.8238 - loss: 0.7641 - val_accuracy: 0.7275 - val_loss: 1.1748
# Epoch 19/20
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 21s 404ms/step - accuracy: 0.8326 - loss: 0.7273 - val_accuracy: 0.7657 - val_loss: 0.9008
# Epoch 20/20
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 41s 400ms/step - accuracy: 0.8477 - loss: 0.7104 - val_accuracy: 0.7493 - val_loss: 0.8952
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 107ms/step - accuracy: 0.7929 - loss: 0.8259
# Validation accuracy: 79.29%

# %% [markdown]
# ## Results and TFLite conversion
#
# With about one million parameters, getting to ~85% top-1 accuracy on 256x256 resolution is
# a strong result. This MobileViT mobile is fully compatible with TensorFlow Lite (TFLite)
# and can be converted with the following code:

# %%
# Serialize the model as a SavedModel.
mobilevit_xxs.export("mobilevit_xxs")

# Convert to TFLite. This form of quantization is called
# post-training dynamic-range quantization in TFLite.
converter = tf.lite.TFLiteConverter.from_saved_model("mobilevit_xxs")
converter.optimizations = [tf.lite.Optimize.DEFAULT]
converter.target_spec.supported_ops = [
    tf.lite.OpsSet.TFLITE_BUILTINS,  # Enable TensorFlow Lite ops.
    tf.lite.OpsSet.SELECT_TF_OPS,  # Enable TensorFlow ops.
]
tflite_model = converter.convert()
open("mobilevit_xxs.tflite", "wb").write(tflite_model)


# Define the destination path in Google Drive
gdrive_path = '/content/drive/My Drive/mobilevit_models'

# Create the directory in Google Drive if it doesn't exist
# !mkdir -p "{gdrive_path}"

# Copy the SavedModel directory
# !cp -r mobilevit_xxs "{gdrive_path}"

# Copy the TFLite model file
# !cp mobilevit_xxs.tflite "{gdrive_path}"

print(f"Models copied to: {gdrive_path}")
# Out:
# Saved artifact at 'mobilevit_xxs'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 256, 256, 3), dtype=tf.float32, name='keras_tensor_171')
# Output Type:
#   TensorSpec(shape=(None, 5), dtype=tf.float32, name=None)
# Captures:
#   133469816113488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133469816117520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133469816118480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133469816117136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133469816117328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133469816117712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133469816119056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133469816118096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133469816117904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133469816118864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133469816118288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133469816120016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133469816119440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133469816119632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133469816119824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133469816116752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133469816120976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133469816120208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133469816120592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133469816120784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133469816121360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133469816121936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133469816120400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133469816121552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133469816121744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133469816118672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133469816122896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133469816122320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133469816122512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133469816122704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133469816119248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133469816123856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133469816123088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133469816123472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133469816123664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133469816124240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133469816124816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133469816123280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133469816124432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133469816124624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133469816121168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133469816125776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133469816125200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133469816125392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133469816125584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133469816122128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133469816126736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133469816125968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133469816126352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133469816126928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133469816127312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133469816125008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133469816124048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133469816126544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133467923186896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133469816126160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133469816127120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133467923185936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133467923186320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133467923186512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133467923186704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133467923187856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133467923187088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133467923187472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133467923187664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133467923188240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133467923188816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133467923187280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133467923188432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133467923188624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133467923185744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133467923189776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133467923189200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133467923189392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133467923189584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133467923186128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133467923190736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133467923189968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133467923191120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133467923191504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133467923190928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133467923192080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133467923190160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133467923190544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133467923191696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133467923192656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133467923189008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133467923193040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133467923192848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133467923188048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133467923193616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133467923194192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133467923191888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133467923193808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133467923192464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133467923191312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133467923194960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133467923194576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133467923190352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133467923194000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133467923195536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133467923196304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133467923195728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133467923196688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133467923196496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133467923192272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133467923197264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133467923197840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133467923193232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133467923197456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133467923196112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133467923195152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133467923198608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133467923196880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133467923199184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133467923199568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133467923198224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133467923199952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133467923198032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133467923197648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133467923199760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133467923200528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133467923194384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133467923198800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133467923200336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133467923195920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133467923201488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133467923200912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133467923199376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133467923201680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133467923201104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133467923201872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133467923200720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133467923200144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133467923201296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133467924234896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133467924236048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133467924235472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133467924235664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133467924234320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133467924236624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133467924235280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133467924237008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133467924236816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133467924234704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133467924237584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133467924238160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133467924235856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133467924237776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133467924236432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133467924235088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133467924238928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133467924238544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133467924234512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133467924237968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133467924239504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133467924240272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133467924239696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133467924240656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133467924240464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133467924236240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133467924241232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133467924241808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133467924237200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133467924241424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133467924240080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133467924239120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133467924242576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133467924242192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133467924238352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133467924241616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133467924243152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133467924243920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133467924243344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133467924244304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133467924244112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133467924239888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133467924244880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133467924245456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133467924240848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133467924245072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133467924243728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133467924242768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133467924246224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133467924245840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133467924242000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133467924245264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133467924246800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133467924247568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133467924246992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133467924247952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133467924247760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133467924243536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133467924248528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133467924249104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133467924244496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133467924248720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133467924247376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133467924246416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133467924249872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133467924248144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133467924249296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133467924250448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133467924250064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133467924245648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133467924249488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133467922187472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133467924247184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133467924248912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133467922187088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133467922186512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133467922186320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133467922186704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133467922188432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133467922187856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133467922188048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133467922188240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133467922187280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133467922189392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133467922188624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133467922189776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133467922190160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133467922189584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133467922190736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133467922188816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133467922189200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133467922190352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133467922191312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133467922187664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133467922191696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133467922191504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133467922186896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133467922192272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133467922192848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133467922190544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133467922192464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133467922191120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133467922189968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133467922193616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133467922193232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133467922189008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133467922192656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133467922194192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133467922194960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133467922194384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133467922195344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133467922195152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133467922190928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133467922195920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133467922196496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133467922191888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133467922196112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133467922194768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133467922193808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133467922197264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133467922196880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133467922193040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133467922196304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133467922197840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133467922198608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133467922198032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133467922198992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133467922198800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133467922194576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133467922199568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133467922200144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133467922195536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133467922199760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133467922198416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133467922197456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133467922200912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133467922199184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133467922201488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133467922201872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133467922200528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133467922202256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133467922201104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133467922200336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133467922196688: TensorSpec(shape=(), dtype=tf.resource, name=None)
# Models copied to: /content/drive/My Drive/mobilevit_models

# %% [markdown]
# To learn more about different quantization recipes available in TFLite and running
# inference with TFLite models, check out
# [this official resource](https://www.tensorflow.org/lite/performance/post_training_quantization).
#
# You can use the trained model hosted on [Hugging Face Hub](https://huggingface.co/keras-io/mobile-vit-xxs)
# and try the demo on [Hugging Face Spaces](https://huggingface.co/spaces/keras-io/Flowers-Classification-MobileViT).

# %% [markdown]
# ## Relevant Chapters from Deep Learning with Python
# - [Chapter 8: Image classification](https://deeplearningwithpython.io/chapters/chapter08_image-classification)
# - [Chapter 15: Language models and the Transformer](https://deeplearningwithpython.io/chapters/chapter15_language-models-and-the-transformer)
